# %%
# @title
def my_function(title,*args,connor,**kwargs):
    print("title :",title)
    print("type of args",type(args))
    print("the random words",args)
    print("type of kwargs",type(kwargs))
    print("the key and values :",kwargs)
    print(connor)
my_function('Function','creed','rocky','apollo',connor='mcgregor',name='adonis creed',bear='lightweight champion')
# Out:
# title : Function
# type of args <class 'tuple'>
# the random words ('creed', 'rocky', 'apollo')
# type of kwargs <class 'dict'>
# the key and values : {'name': 'adonis creed', 'bear': 'lightweight champion'}
# mcgregor
